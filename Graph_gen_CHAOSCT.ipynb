# %%
import os
import plotly
import plotly.figure_factory as ff
import plotly.graph_objs as go
import shutil
import time
import plotly.io as pio
import glob
import json
import statistics
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#------------------------------------GENERATE GRAPH WITH MEAN POINTS------------------------------------------------

file_dict={}
var_dict={}

psnr,bpp=[],[]

trace1_main=[]
trace2_main=[]
trace3_main=[]


file_dict['Arch_1_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch1_waac.json')
file_dict['Arch_1_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch1_waac.json')
file_dict['Arch_1_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch1_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_1_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0
        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):

            mean_y.append(statistics.mean(psnr[i]))
            mean_x.append(statistics.mean(new_bpp[i]))
            i=i+1
            
    trace1 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'cross', 'size': 6,'color':'red'},
    mode = 'lines+markers',
            line = dict(
    width = 2),
        legendgroup='Arch1',
    name = 'A=1, Adverserial')
    
    trace2 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'diamond', 'size': 6,'color':'red'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
        legendgroup='Arch1',
    name = 'A=1, Quantizer in inference')
 
    trace3 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'circle', 'size': 6,'color':'red'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
        legendgroup='Arch1',
    name = 'A=1, Quantizer in training')

    
    trace1_main.append(trace1)
    trace2_main.append(trace2)
    trace3_main.append(trace3)
    
file_dict['Arch_2_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch2_waac.json')
file_dict['Arch_2_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch2_waac.json')
file_dict['Arch_2_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch2_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_2_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0
        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            mean_y.append(statistics.mean(psnr[i]))
            mean_x.append(statistics.mean(new_bpp[i]))
            i=i+1
            
    trace1 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'cross', 'size':6,'color':'green'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
        legendgroup='Arch2',
    name = 'A=2, Adverserial'
  )
    
    trace2 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'diamond', 'size':6,'color':'green'},
        line = dict(
    width = 2),
    mode = 'lines+markers',
        legendgroup='Arch2',
    name = 'A=2, Quantizer in inference'
  )
 
    trace3 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'circle', 'size':6,'color':'green'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
        legendgroup='Arch2',
    name = 'A=2, Quantizer in training')

    
    trace1_main.append(trace1)
    trace2_main.append(trace2)
    trace3_main.append(trace3)

                  

file_dict['Arch_3_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch3_waac.json')
file_dict['Arch_3_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch3_waac.json')
file_dict['Arch_3_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch3_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_3_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0
        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            mean_y.append(statistics.mean(psnr[i]))
            mean_x.append(statistics.mean(new_bpp[i]))
            i=i+1
            
    trace1 = go.Scatter(
    x = mean_x,
    y = mean_y,
            line = dict(
    width = 2),
    marker={'symbol': 'cross', 'size': 6,'color':'violet'},
    mode = 'lines+markers',
        legendgroup='Arch3',
    name = 'A=3, Adverserial'
  )
    
    trace2 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'diamond', 'size': 6,'color':'violet'},
    mode = 'lines+markers',
            line = dict(
    width = 2),
        legendgroup='Arch3',
    name = 'A=3, Quantizer in infernece'
  )
 
    trace3 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'circle', 'size': 6,'color':'violet'},
    mode = 'lines+markers',
            line = dict(
    width = 2),
        legendgroup='Arch3',
    name = 'A=3, Quantizer in training')

    
    trace1_main.append(trace1)
    trace2_main.append(trace2)
    trace3_main.append(trace3)
    
file_dict['Arch_4_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch4_waac.json')
file_dict['Arch_4_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch4_waac.json')
file_dict['Arch_4_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch4_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_4_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0
        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            mean_y.append(statistics.mean(psnr[i]))
            mean_x.append(statistics.mean(new_bpp[i]))
            i=i+1
            
    trace1 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'cross', 'size': 6,'color':'blue'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
    legendgroup='Arch4',
    name = 'A=4, Adverserial'
  )
    
    trace2 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'diamond', 'size': 6,'color':'blue'},
    mode = 'lines+markers',
        line = dict(
    width = 2),
        legendgroup='Arch4',
    name = 'A=4, Quantizer in inference'
  )
 
    trace3 = go.Scatter(
    x = mean_x,
    y = mean_y,
    marker={'symbol': 'circle', 'size': 6,'color':'blue'},
    line = dict(
    width = 2),
    mode = 'lines+markers',
        legendgroup='Arch4',
    name = 'A=4, Quantizer in training')

    
    trace1_main.append(trace1)
    trace2_main.append(trace2)
    trace3_main.append(trace3)  
    
    
data=[trace1_main[0],trace2_main[1],trace3_main[2],trace1_main[3],trace2_main[4],trace3_main[5],trace1_main[6],trace2_main[7],trace3_main[8],trace1_main[9],trace2_main[10],trace3_main[11]]
layout = go.Layout(
    title='Dataset: CHAOSCT, Metric:pSNR, AAC:Yes',
xaxis=dict(
        title='Compression Factor',
        tickmode='linear',
        ticks='outside',

        showgrid=True,
        
        type='log',
        zeroline=True,
        showline=True,

        autorange=True
    ),
    yaxis=dict(
        title='pSNR',
        tickmode='linear',
        ticks='outside',
        tick0=0,
        zeroline=True,
        showline=True,
       
        dtick=2,

    )
)
fig = dict(data=data,layout=layout)
plotly.offline.iplot(fig, filename='Mean_graph')
 
        



    



pio.write_image(fig, 'images/CHAOSCT/Mean_Graph.png')
# Out:
# <div>
#
#
#             <div id="971392e3-5108-4156-9123-3f901c2d86d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("971392e3-5108-4156-9123-3f901c2d86d9")) {
#                     Plotly.newPlot(
#                         '971392e3-5108-4156-9123-3f901c2d86d9',
# ...

# %%
file_dict={}
var_dict={}

psnr,bpp=[],[]

file_dict['Arch_1_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch1_waac.json')
file_dict['Arch_1_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch1_waac.json')
file_dict['Arch_1_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch1_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_1_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0

        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            x = new_bpp[i]
            y = psnr[i]
            img_name='PointCloud A1L'+str(count)+'P'+str(i)

            colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]


            fig = ff.create_2d_density(
                x, y, colorscale=colorscale,
                title='PointCloud',
                hist_color='rgb(255, 237, 222)',point_color='rgb(255,255,255)', point_size=5

            )

            plotly.offline.iplot(fig )
            pio.write_image(fig, 'images/CHAOSCT/PSNR_wAAC/'+img_name+'.png')

            i=i+1
            
file_dict['Arch_2_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch2_waac.json')
file_dict['Arch_2_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch2_waac.json')
file_dict['Arch_2_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch2_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_2_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0

        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            x = new_bpp[i]
            y = psnr[i]
            img_name='PointCloud A2L'+str(count)+'P'+str(i)

            colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]


            fig = ff.create_2d_density(
                x, y, colorscale=colorscale,
                title='PointCloud',
                hist_color='rgb(255, 237, 222)',point_color='rgb(255,255,255)', point_size=5

            )

            plotly.offline.iplot(fig )
            pio.write_image(fig, 'images/CHAOSCT/PSNR_wAAC/'+img_name+'.png')

            i=i+1
            

            

file_dict['Arch_3_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch3_waac.json')
file_dict['Arch_3_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch3_waac.json')
file_dict['Arch_3_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch3_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_3_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0

        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            x = new_bpp[i]
            y = psnr[i]
            img_name='PointCloud A3L'+str(count)+'P'+str(i)

            colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]


            fig = ff.create_2d_density(
                x, y, colorscale=colorscale,
                title='PointCloud',
                hist_color='rgb(255, 237, 222)',point_color='rgb(255,255,255)', point_size=5

            )

            plotly.offline.iplot(fig )
            pio.write_image(fig, 'images/CHAOSCT/PSNR_wAAC/'+img_name+'.png')

            i=i+1
            

            

file_dict['Arch_4_1']=open('/home/rakshith/Desktop/CHAOSCT/adver/arch4_waac.json')
file_dict['Arch_4_2']=open('/home/rakshith/Desktop/CHAOSCT/normal/quaninf_arch4_waac.json')
file_dict['Arch_4_3']=open('/home/rakshith/Desktop/CHAOSCT/quantrain/quantrain_arch4_waac.json')
for count in range(1,4):

    
    with (file_dict['Arch_4_'+str(count)]) as json_file: 
        
        data = json.load(json_file)
        psnr,bpp=[],[]
        new_bpp=[]
#         mean_x,mean_y=[]

        for p in data:
            psnr.append(p['psnr'])
            bpp.append(p['bpp'])
            
        for row in bpp:

            row[:]=([16 / x for x in row])
            
            new_bpp.append(row[:])

        i=0

        mean_x,mean_y=[],[]
       
        while(i<len(psnr)):
            x = new_bpp[i]
            y = psnr[i]
            img_name='PointCloud A4L'+str(count)+'P'+str(i)

            colorscale = ['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)]


            fig = ff.create_2d_density(
                x, y, colorscale=colorscale,
                title='PointCloud',
                hist_color='rgb(255, 237, 222)',point_color='rgb(255,255,255)', point_size=5

            )

            plotly.offline.iplot(fig )
            pio.write_image(fig, 'images/CHAOSCT/PSNR_wAAC/'+img_name+'.png')

            i=i+1
# Out:
# <div>
#
#
#             <div id="5156fb00-9fa9-4c55-bb70-20cc6fb66c9b" class="plotly-graph-div" style="height:600px; width:600px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5156fb00-9fa9-4c55-bb70-20cc6fb66c9b")) {
#                     Plotly.newPlot(
#                         '5156fb00-9fa9-4c55-bb70-20cc6fb66c9b',
# ...
